# %% [markdown]
# #### Necessary imports

# %%
from methods_data_collection import *

# %%
tqdm.pandas()

# %% [markdown]
# # Visual data collection
# This notebook contains the data collection for the following datasets:
# 1. Train/test data required for building a facial recognition model for politicians
# 2. News images data: </br>
#    a. NOS.nl </br>
#    b. NU.nl </br>

# %% [markdown]
# ## 1. Train/test data required for building a facial recognition system
# ##### Set up data infrastructure
# Load references obtained in script #2 of this directory, create a test set

# %%
# Read the collected training set image links
bing_img = pd.read_excel('datasets/bing_img_links.xlsx')
ddg_img = pd.read_excel('datasets/ddg_img_links.xlsx')
ecosia_img = pd.read_excel('datasets/ecosia_img_links.xlsx')

# Ensure that the 'restricted access' error arising with some ecosia links is prevented
ecosia_img['img_link'] = ecosia_img['img_link'].apply(lambda x: x.replace('explicit', 'mm'))

# Concatenate all training set image links into one file
img_links_bing_ddg = pd.concat([bing_img, ddg_img])
img_links = pd.concat([img_links_bing_ddg, ecosia_img])
img_links = img_links[['politician', 'img_link']]

# %%
img_links.to_excel('datasets/all_train_img_links.xlsx')

# %%
print(img_links.shape)
print(img_links.columns)
# Out:
# (6375, 2)
# Index(['politician', 'img_link'], dtype='object')

# %%
test_set = img_links.sample(n = 50, random_state = 0)

# %%
test_set.to_excel('datasets/test_set_img_links.xlsx')

# %% [markdown]
# ### Open images online, apply face detection and store isolated faces to file

# %% [markdown]
# #### Test if methods work as expected, including print statements

# %%
from methods_data_collection import detect_cut_save_faces_test

# Create the output directory
output_dir_traintest_test = 'datasets/images/isolated_train_faces_scraped_test'
os.makedirs(output_dir_traintest_test, exist_ok=True)

detect_cut_save_faces_test(test_set, 'img_link', 'politician', output_dir_traintest_test)
# Out:
# Test scraping at...:   0%|          | 0/50 [00:00<?, ?it/s]
# Laurens Dassen with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.0OMU0vd2yrf-r_zxLsQ3SQHaFB%26pid%3DApi&f=1&ipt=2011936aaf234ece1724886e8828f5e80ebb8b7fc9acd9664579d44a7a1b7c5a&ipo=images
# #HAAR: 1 at: [[250  70 126 126]]
# #FR: 1 at: [(259, 92, 107, 107)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([250,  70, 126, 126], dtype=int32)]
#
# Lilian Marijnissen with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.Yo4LgZO6FffHRksLETWEGQHaE7%26pid%3DApi&f=1&ipt=246a912344e1bdb873b06ee2e3e054b88ff0e33cdc42feb9ec4b58309d456795&ipo=images
# #HAAR: 1 at: [[257  67 119 119]]
# #FR: 1 at: [(259, 80, 107, 107)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([257,  67, 119, 119], dtype=int32)]
#
# Pieter Omtzigt with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.J4r3CPGdywulbxlqwYlekAHaE7%26pid%3DApi&f=1&ipt=29275d7c034d8dc47acfa0c82f686a304f5c484316b2fa9b3985b8463f043bc5&ipo=images
# #HAAR: 1 at: [[295  69  83  83]]
# #FR: 1 at: [(295, 80, 75, 75)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([295,  69,  83,  83], dtype=int32)]
#
# Henri Bontebal with image url: https://th.bing.com/th/id/OIP.rYzsBTk_pkUo0EyzTiAQ7QHaD0?w=387&h=179&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Esther Ouwehand with image url: https://th.bing.com/th/id/OIP.NQ6iojYJoCWad-9xuButYQHaEf?w=271&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 2 at: [[258 100  65  65]
#  [167  42  74  74]]
# #FR: 2 at: [(259, 108, 63, 62), (170, 53, 62, 62)]
# #COMBINED: 4
# #UNIQUE: 2 at: [array([258, 100,  65,  65], dtype=int32), array([167,  42,  74,  74], dtype=int32)]
#
# Mirjam Bikker with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.JshCIqMKCA8lUDojUpicXgAAAA%26pid%3DApi&f=1&ipt=b59261baaa2b4330bca6cdc7c909598c33eff452de53d875ae81eea2b19ab511&ipo=images
# #HAAR: 2 at: [[378  84  39  39]
#  [222  38  80  80]]
# #FR: 3 at: [(229, 47, 74, 74), (354, 26, 86, 90), (121, 32, 62, 62)]
# #COMBINED: 5
# #UNIQUE: 4 at: [array([378,  84,  39,  39], dtype=int32), array([222,  38,  80,  80], dtype=int32), (354, 26, 86, 90), (121, 32, 62, 62)]
#
# Thierry Baudet with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.sxXiHJWrKon2kJBZcH3ZawHaE8%26pid%3DApi&f=1&ipt=117db1971948c67299eaf1b00621863312ad04a43a145931d5ec632cb8cbaee3&ipo=images
# #HAAR: 1 at: [[170  73 143 143]]
# #FR: 1 at: [(167, 81, 155, 155)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([170,  73, 143, 143], dtype=int32)]
#
# Wybren van Haga with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.m39Lj8Uki9zVyw93dGuDVQHaEK%26pid%3DApi&f=1&ipt=1b421a13d99085b02e0ccd641c018fe00a8811a5985a59f050a13384e3881766&ipo=images
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Pieter Omtzigt with image url: https://tse1.mm.bing.net/th?id=OIP.4mcZOW9P0q6JUWSBKbtUGgHaD0&pid=Api
# #HAAR: 1 at: [[188  36 121 121]]
# #FR: 1 at: [(199, 44, 107, 108)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([188,  36, 121, 121], dtype=int32)]
#
# Laurens Dassen with image url: https://tse4.mm.bing.net/th?id=OIP.LSt0jixTxl1Y2lSC9gV9XQHaEK&pid=Api
# #HAAR: 1 at: [[182  65  58  58]]
# #FR: 1 at: [(181, 72, 52, 52)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([182,  65,  58,  58], dtype=int32)]
#
# Henri Bontebal with image url: https://tse1.mm.bing.net/th?id=OIP._0EGpbJgohchM-bKTshtZQHaEK&pid=Api
# #HAAR: 1 at: [[153  31 170 170]]
# #FR: 1 at: [(167, 67, 129, 129)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([153,  31, 170, 170], dtype=int32)]
#
# Laurens Dassen with image url: https://th.bing.com/th/id/OIP.C-AQLDcTIa5CKmUrNrvdFAHaHa?w=149&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[ 47  48 196 196]]
# #FR: 1 at: [(64, 81, 154, 155)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([ 47,  48, 196, 196], dtype=int32)]
#
# Henri Bontebal with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.ievY3LlaqX3IVnfqPFRzLwHaLG%26pid%3DApi&f=1&ipt=07ca640ecff0fc0a06dfeeeb23933700773f86064f53449428715de5454ec9b9&ipo=images
# Lilian Marijnissen with image url: https://tse1.mm.bing.net/th?id=OIP.e3GWVPuS_EeBtudF4CizdwHaEl&pid=Api
# #HAAR: 1 at: [[ 21  35 213 213]]
# #FR: 2 at: [(35, 57, 186, 185), (393, 150, 36, 36)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([ 21,  35, 213, 213], dtype=int32), (393, 150, 36, 36)]
#
# Joost Eerdmans with image url: https://th.bing.com/th/id/OIP.NJZdF5FDUrh9R5PPp2FwiQAAAA?w=75&h=100&c=7&r=0&o=5&dpr=2&pid=1.7
# Pieter Omtzigt with image url: https://th.bing.com/th/id/OIP.EG1s-KprqfXWKfOeDhym5wHaEK?w=291&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 2 at: [[121  37  89  89]
#  [276 204  55  55]]
# #FR: 1 at: [(103, 32, 108, 108)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([121,  37,  89,  89], dtype=int32), array([276, 204,  55,  55], dtype=int32)]
#
# Rob Jetten with image url: https://tse3.mm.bing.net/th?id=OIP.E3l-c6zDIBfDUBqkgGp_BwHaFS&pid=Api
# #HAAR: 1 at: [[121  34  61  61]]
# #FR: 1 at: [(124, 38, 51, 52)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([121,  34,  61,  61], dtype=int32)]
#
# Wybren van Haga with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.Oe8mi3nvY8zXEavi5N0kZQHaDt%26pid%3DApi&f=1&ipt=3ab017fc5b2f03e08586818f5d79548881486be0745735d462af6a6ff805d072&ipo=images
# #HAAR: 1 at: [[327 171  58  58]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([327, 171,  58,  58], dtype=int32)]
#
# Esther Ouwehand with image url: https://tse1.mm.bing.net/th?id=OIP.HDcnnK3W78JY2ggj5A_8bwHaD7&pid=Api
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Rob Jetten with image url: https://th.bing.com/th/id/OIP.AWrQKKZ9O1hwEHpcVpBveAHaFV?w=276&h=199&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[186  78 167 167]]
# #FR: 1 at: [(184, 98, 155, 155)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([186,  78, 167, 167], dtype=int32)]
#
# Frans Timmermans with image url: https://tse4.mm.bing.net/th?id=OIP.-HR_brNBlFzaGZZJjTdupAHaEa&pid=Api
# #HAAR: 1 at: [[196  37 104 104]]
# #FR: 1 at: [(187, 44, 107, 108)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([196,  37, 104, 104], dtype=int32)]
#
# Geert Wilders with image url: https://tse1.mm.bing.net/th?id=OIP.dvStCnziDh3KNBjHBzypngHaEK&pid=Api
# #HAAR: 1 at: [[175  51 143 143]]
# #FR: 1 at: [(182, 67, 129, 129)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([175,  51, 143, 143], dtype=int32)]
#
# Geert Wilders with image url: https://tse2.mm.bing.net/th?id=OIP.8LS2aoHwqGJnjUsuhz2kDAHaJQ&pid=Api
# #HAAR: 1 at: [[204  85 229 229]]
# #FR: 1 at: [(191, 118, 223, 223)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([204,  85, 229, 229], dtype=int32)]
#
# Laurens Dassen with image url: https://th.bing.com/th/id/OIP.f8zDCbi4ABqYcL5GVMcLwgHaE8?w=267&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 0 at: ()
# #FR: 1 at: [(216, 90, 52, 51)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(216, 90, 52, 51)]
#
# Laurens Dassen with image url: https://th.bing.com/th/id/OIP.6IyqDyEMMX0t74M3F7EA5wHaE8?w=272&h=182&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Thierry Baudet with image url: https://tse4.mm.bing.net/th?id=OIP.WyuGoJ7b5OmEq2FkfP06rwHaE8&pid=Api
# #HAAR: 2 at: [[241 118 108 108]
#  [122  33 112 112]]
# #FR: 1 at: [(235, 128, 107, 107)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([241, 118, 108, 108], dtype=int32), array([122,  33, 112, 112], dtype=int32)]
#
# Frans Timmermans with image url: https://th.bing.com/th/id/OIP.1XwOTjpfm_cs81Zh1jzmJwHaEK?w=282&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[ 87  38 209 209]]
# #FR: 1 at: [(118, 57, 186, 185)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([ 87,  38, 209, 209], dtype=int32)]
#
# Mirjam Bikker with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.O6NmXeWIIeLuEpsRsrtE4AAAAA%26pid%3DApi&f=1&ipt=fdf6ad868a4babeaa48ce22c1803d4eb5643bc5b32e0d03ec8c179ebac0d3d8c&ipo=images
# #HAAR: 1 at: [[179  28  43  43]]
# #FR: 1 at: [(181, 34, 36, 36)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([179,  28,  43,  43], dtype=int32)]
#
# Mirjam Bikker with image url: https://th.bing.com/th/id/OIP.vQXIlm3z_a_uoo9kt-NbUgHaDl?w=308&h=169&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 2 at: [[129  13 138 138]
#  [296 109 107 107]]
# #FR: 1 at: [(139, 24, 129, 129)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([129,  13, 138, 138], dtype=int32), array([296, 109, 107, 107], dtype=int32)]
#
# Esther Ouwehand with image url: https://th.bing.com/th/id/OIP.Q2iGjeRtvogngPZ29I7p4QHaE8?w=255&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[122  25 204 204]]
# #FR: 1 at: [(150, 64, 154, 155)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([122,  25, 204, 204], dtype=int32)]
#
# Lilian Marijnissen with image url: https://th.bing.com/th/id/OIP.IShZ7ltY1e9pM_Yp9X9FXgHaEK?w=314&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[204  28 110 110]]
# #FR: 1 at: [(215, 46, 90, 90)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([204,  28, 110, 110], dtype=int32)]
#
# Joost Eerdmans with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.OK1fPXfoSqZA4-_TDY-h5AHaEi%26pid%3DApi&f=1&ipt=a0c5a9af736ca9c27a0387a6c2465257024347dc510e1f2ca37a73514139238a&ipo=images
# Stephan van Baarle with image url: https://tse2.mm.bing.net/th?id=OIP.JPp9SH9NSKtbG7rqZt0Y8AHaF4&pid=Api
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Rob Jetten with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.eDzDs6I93ob6zffH7nW5KQHaD3%26pid%3DApi&f=1&ipt=cee874031679ed9cd19a6b8c00f7d60dce38d0f00a40b1453c3de5d2ab5fdd2c&ipo=images
# #HAAR: 0 at: ()
# #FR: 1 at: [(170, 101, 52, 52)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(170, 101, 52, 52)]
#
# Henri Bontebal with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.mTqXy4VurpRBWx1d2PW4GAHaI9%26pid%3DApi&f=1&ipt=368e6e9435890abef0c880d87c00b5b945a46acca6c5156a14fea9f2330413cc&ipo=images
# #HAAR: 1 at: [[ 88 147 327 327]]
# #FR: 1 at: [(111, 201, 268, 267)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([ 88, 147, 327, 327], dtype=int32)]
#
# Esther Ouwehand with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.I4voSPlWyU60NYpskSp6sgHaE3%26pid%3DApi&f=1&ipt=eacf3f9ddc3cecfb82fb51e51f7100cf5e7081a963945c0dd5488c4d8275c464&ipo=images
# #HAAR: 1 at: [[154  68  81  81]]
# #FR: 1 at: [(163, 80, 62, 62)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([154,  68,  81,  81], dtype=int32)]
#
# Kees van der Staaij with image url: https://tse3.mm.bing.net/th?id=OIP.m_-ZU19rvZl1FBltQ-6ONQHaEK&pid=Api
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Wybren van Haga with image url: https://tse4.mm.bing.net/th?id=OIP.1ZwTuKvRANM6osrDMp515QHaE2&pid=Api
# #HAAR: 0 at: ()
# #FR: 1 at: [(187, 56, 107, 107)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(187, 56, 107, 107)]
#
# Henri Bontebal with image url: https://tse2.mm.bing.net/th?id=OIP.8w2AZnPkDT0NiWNNEHLa3wHaGP&pid=Api
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Frans Timmermans with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.LWTn45o16UoydXhknZe9hgHaEK%26pid%3DApi&f=1&ipt=a3a1bafd0f0bba97ba116f9bfc1231b2d148963913ba29d8accedd924512d6ff&ipo=images
# #HAAR: 1 at: [[214  38  95  95]]
# #FR: 1 at: [(215, 56, 90, 90)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([214,  38,  95,  95], dtype=int32)]
#
# Edson Olf with image url: https://tse3.mm.bing.net/th?id=OIP.0L7mn_k29VJkGZ3admj4LAHaE7&pid=Api
# #HAAR: 1 at: [[210  19  62  62]]
# #FR: 1 at: [(216, 32, 52, 52)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([210,  19,  62,  62], dtype=int32)]
#
# Caroline van der Plas with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse2.mm.bing.net%2Fth%3Fid%3DOIP.eXujrfem9jT-8m7rOvWMFQHaE7%26pid%3DApi&f=1&ipt=59d3c92c7c9716d2b0e5d4c0fc20eafb435ed6d0b690837ee8a91adf612b1719&ipo=images
# #HAAR: 1 at: [[ 82  65 111 111]]
# #FR: 1 at: [(91, 80, 108, 107)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([ 82,  65, 111, 111], dtype=int32)]
#
# Kees van der Staaij with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse1.mm.bing.net%2Fth%3Fid%3DOIP.8s3ZxAOtu0d08sfIH3faswHaEK%26pid%3DApi&f=1&ipt=f53bc57ddf6afee5c23ea8e51fcf6f2a1cf22196f56ccdd4ad166651717d1c6c&ipo=images
# #HAAR: 1 at: [[204  34  85  85]]
# #FR: 1 at: [(212, 47, 75, 74)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([204,  34,  85,  85], dtype=int32)]
#
# Rob Jetten with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse4.mm.bing.net%2Fth%3Fid%3DOIP.SBQTHxe2iai-mmTEQqpZowHaEK%26pid%3DApi&f=1&ipt=87802b9e76621c6d5f2937454811ecd7a65fce636f4234c1a52791fdeeeec410&ipo=images
# #HAAR: 1 at: [[204  53 122 122]]
# #FR: 1 at: [(211, 56, 107, 107)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([204,  53, 122, 122], dtype=int32)]
#
# Wybren van Haga with image url: https://th.bing.com/th/id/OIP.IDFGPCT8gqF3SZ575euiyQHaEv?w=271&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[149  67 147 147]]
# #FR: 1 at: [(153, 82, 129, 129)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([149,  67, 147, 147], dtype=int32)]
#
# Laurens Dassen with image url: https://tse4.mm.bing.net/th?id=OIP.b2UnC0WM5wRTinEZAZ_DPwHaHa&pid=Api
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# Frans Timmermans with image url: https://th.bing.com/th/id/OIP.KB6SlkiHbogc5xN1UqOhagHaEL?w=280&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 3 at: [[ 13  30 110 110]
#  [239  39 110 110]
#  [ 94  13 164 164]]
# #FR: 3 at: [(8, 44, 107, 108), (98, 30, 155, 154), (245, 56, 90, 90)]
# #COMBINED: 6
# #UNIQUE: 3 at: [array([ 13,  30, 110, 110], dtype=int32), array([239,  39, 110, 110], dtype=int32), array([ 94,  13, 164, 164], dtype=int32)]
#
# Esther Ouwehand with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.HF74Rv3-gkBa3Yv5RoPUSgHaE7%26pid%3DApi&f=1&ipt=f54791332145cc033557a2c96912640e8c534474a368a0684c0753decdb7d280&ipo=images
# #HAAR: 1 at: [[175  35 114 114]]
# #FR: 1 at: [(175, 56, 107, 107)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([175,  35, 114, 114], dtype=int32)]
#
# Dilan Yesilgöz with image url: https://th.bing.com/th/id/OIP.OJGAgecom7JmXe6crXmh2QHaEK?w=307&h=180&c=7&r=0&o=5&dpr=2&pid=1.7
# #HAAR: 1 at: [[171  42 105 105]]
# #FR: 1 at: [(175, 56, 90, 90)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([171,  42, 105, 105], dtype=int32)]
#
# Mirjam Bikker with image url: https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Ftse3.mm.bing.net%2Fth%3Fid%3DOIP.W4FwvW22Q-Kxqrva6Bx-FQHaE6%26pid%3DApi&f=1&ipt=6127ac2f3bac39068774461cfbc69757dd0438aed4f4f74e456957e1e12713b6&ipo=images
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []

# %% [markdown]
# ### Continue to full dataset after inspection

# %%
from methods_data_collection import detect_cut_save_faces

# Create the output directory
output_dir_traintest = 'datasets/images/isolated_train_faces_scraped_uncorrected'
os.makedirs(output_dir_traintest, exist_ok=True)

detect_cut_save_faces(img_links, 'img_link', 'politician', output_dir_traintest)
# Out:
# Scraping at...:   0%|          | 0/6375 [00:00<?, ?it/s]

# %% [markdown]
# ## 2. News images data
# ### a. NOS.nl
#
# ##### Set up data infrastructure
# Load articles that are not exclusively about sports obtained in script #1 of this directory, create a test set

# %%
nos_articles = pd.read_parquet('datasets/nos_articles_election_period_no_sports.parquet')
nos_articles['img_link'] = nos_articles['images'].astype(str).apply(lambda url: url.strip("['']"))

# %%
print(nos_articles.shape)
print(nos_articles.columns)
# Out:
# (4707, 13)
# Index(['id', 'title', 'datetime', 'owner', 'type', 'url', 'date', 'time',
#        'category', 'images', 'alt_txt', 'paragraphs', 'img_link'],
#       dtype='object')

# %%
nos_articles_test = nos_articles.sample(n = 50, random_state = 0)

# %% [markdown]
# #### Test if methods work as expected, including print statements

# %%
from methods_data_collection import detect_cut_save_faces_test

# Create the output directory
output_dir_news_nos_test = 'datasets/images/isolated_news_faces_nos_test'
os.makedirs(output_dir_news_nos_test, exist_ok=True)

detect_cut_save_faces_test(nos_articles_test, 'img_link', 'id', output_dir_news_nos_test)
# Out:
# Test scraping at...:   0%|          | 0/50 [00:00<?, ?it/s]
# 2496413 with image url: https://cdn.nos.nl/image/2023/11/03/1022523/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2491905 with image url: https://cdn.nos.nl/image/2023/09/26/1011627/1024x576a.jpg
# #HAAR: 2 at: [[806 265  53  53]
#  [376  81 379 379]]
# #FR: 1 at: [(419, 134, 321, 321)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([806, 265,  53,  53], dtype=int32), array([376,  81, 379, 379], dtype=int32)]
#
# 2493815 with image url: https://cdn.nos.nl/image/2023/10/12/1016208/1024x576a.jpg
# #HAAR: 1 at: [[904  54  53  53]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([904,  54,  53,  53], dtype=int32)]
#
# 2496602 with image url: https://cdn.nos.nl/image/2023/11/04/1022975/1024x576a.jpg
# #HAAR: 2 at: [[621 191  38  38]
#  [868 266  54  54]]
# #FR: 3 at: [(366, 98, 185, 186), (621, 194, 36, 36), (871, 271, 43, 43)]
# #COMBINED: 5
# #UNIQUE: 3 at: [array([621, 191,  38,  38], dtype=int32), array([868, 266,  54,  54], dtype=int32), (366, 98, 185, 186)]
#
# 2496801 with image url: https://cdn.nos.nl/image/2023/11/05/1023581/1024x576a.jpg
# #HAAR: 1 at: [[598 435  61  61]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([598, 435,  61,  61], dtype=int32)]
#
# 2503222 with image url: https://cdn.nos.nl/image/2023/12/30/1039335/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2497388 with image url: https://cdn.nos.nl/image/2023/11/10/1024991/1024x576a.jpg
# #HAAR: 3 at: [[123 234  66  66]
#  [538 255  62  62]
#  [861 245  71  71]]
# #FR: 3 at: [(121, 229, 75, 75), (527, 246, 75, 74), (867, 254, 75, 75)]
# #COMBINED: 6
# #UNIQUE: 3 at: [array([123, 234,  66,  66], dtype=int32), array([538, 255,  62,  62], dtype=int32), array([861, 245,  71,  71], dtype=int32)]
#
# 2499298 with image url: https://cdn.nos.nl/image/2023/11/26/1029655/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2501774 with image url: https://cdn.nos.nl/image/2023/12/16/1035831/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2491066 with image url: https://cdn.nos.nl/image/2023/09/19/1009504/1024x576a.jpg
# #HAAR: 1 at: [[469 149  80  80]]
# #FR: 1 at: [(517, 186, 36, 36)]
# #COMBINED: 2
# #UNIQUE: 2 at: [array([469, 149,  80,  80], dtype=int32), (517, 186, 36, 36)]
#
# 2489664 with image url: https://cdn.nos.nl/image/2023/09/08/1006072/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 1 at: [(822, 285, 90, 90)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(822, 285, 90, 90)]
#
# 2502919 with image url: https://cdn.nos.nl/image/2023/12/27/1038562/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2501641 with image url:
# 2498166 with image url: https://cdn.nos.nl/image/2023/11/17/1026847/1024x576a.jpg
# #HAAR: 1 at: [[364  86 141 141]]
# #FR: 1 at: [(368, 110, 129, 129)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([364,  86, 141, 141], dtype=int32)]
#
# 2489825 with image url: https://cdn.nos.nl/image/2023/09/09/1006473/1024x576a.jpg
# #HAAR: 2 at: [[252  68 270 270]
#  [ 16 470  60  60]]
# #FR: 1 at: [(291, 118, 222, 223)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([252,  68, 270, 270], dtype=int32), array([ 16, 470,  60,  60], dtype=int32)]
#
# 2489509 with image url: https://cdn.nos.nl/image/2023/09/06/1005714/1024x576a.jpg
# #HAAR: 1 at: [[388 410  67  67]]
# #FR: 1 at: [(415, 84, 43, 43)]
# #COMBINED: 2
# #UNIQUE: 2 at: [array([388, 410,  67,  67], dtype=int32), (415, 84, 43, 43)]
#
# 2497003 with image url: https://cdn.nos.nl/image/2023/11/07/1024026/1024x576a.jpg
# #HAAR: 1 at: [[334  92 374 374]]
# #FR: 1 at: [(379, 171, 267, 268)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([334,  92, 374, 374], dtype=int32)]
#
# 2500679 with image url: https://cdn.nos.nl/image/2023/12/07/1033030/1024x576a.jpg
# #HAAR: 3 at: [[381 144  62  62]
#  [818 125  62  62]
#  [491 132  70  70]]
# #FR: 5 at: [(486, 130, 74, 74), (383, 153, 52, 52), (819, 129, 62, 62), (434, 180, 43, 43), (526, 53, 129, 129)]
# #COMBINED: 8
# #UNIQUE: 5 at: [array([381, 144,  62,  62], dtype=int32), array([818, 125,  62,  62], dtype=int32), array([491, 132,  70,  70], dtype=int32), (434, 180, 43, 43), (526, 53, 129, 129)]
#
# 2494851 with image url: https://cdn.nos.nl/image/2023/10/21/1018611/1024x576a.jpg
# #HAAR: 2 at: [[430 118 126 126]
#  [ 15 179 157 157]]
# #FR: 0 at: []
# #COMBINED: 2
# #UNIQUE: 2 at: [array([430, 118, 126, 126], dtype=int32), array([ 15, 179, 157, 157], dtype=int32)]
#
# 2493323 with image url: https://cdn.nos.nl/image/2023/10/08/1015078/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2491033 with image url: https://cdn.nos.nl/image/2023/09/19/1009361/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2493799 with image url: https://cdn.nos.nl/image/2023/10/12/1016178/1024x576a.jpg
# #HAAR: 2 at: [[425  74  46  46]
#  [547 230  91  91]]
# #FR: 1 at: [(399, 92, 462, 462)]
# #COMBINED: 3
# #UNIQUE: 3 at: [array([425,  74,  46,  46], dtype=int32), array([547, 230,  91,  91], dtype=int32), (399, 92, 462, 462)]
#
# 2494791 with image url: https://cdn.nos.nl/image/2023/10/21/1018461/1024x576a.jpg
# #HAAR: 1 at: [[242  85 447 447]]
# #FR: 1 at: [(245, 143, 462, 433)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([242,  85, 447, 447], dtype=int32)]
#
# 2500895 with image url: https://cdn.nos.nl/image/2023/12/09/1033548/1024x576a.jpg
# #HAAR: 3 at: [[820 303  65  65]
#  [816 326  69  69]
#  [625 433 100 100]]
# #FR: 0 at: []
# #COMBINED: 3
# #UNIQUE: 3 at: [array([820, 303,  65,  65], dtype=int32), array([816, 326,  69,  69], dtype=int32), array([625, 433, 100, 100], dtype=int32)]
#
# 2498186 with image url: https://cdn.nos.nl/image/2023/11/17/1026889/1024x576a.jpg
# #HAAR: 2 at: [[377  98 201 201]
#  [225 216 108 108]]
# #FR: 1 at: [(386, 139, 186, 186)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([377,  98, 201, 201], dtype=int32), array([225, 216, 108, 108], dtype=int32)]
#
# 2492957 with image url: https://cdn.nos.nl/image/2023/10/05/1014022/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2499902 with image url: https://cdn.nos.nl/image/2023/12/01/1031124/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2492606 with image url: https://cdn.nos.nl/image/2023/10/02/1013240/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 1 at: [(458, 164, 52, 52)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(458, 164, 52, 52)]
#
# 2492467 with image url: https://cdn.nos.nl/image/2023/10/01/1012887/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2495257 with image url: https://cdn.nos.nl/image/2023/10/24/1019611/1024x576a.jpg
# #HAAR: 1 at: [[541 121 183 183]]
# #FR: 1 at: [(562, 167, 155, 155)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([541, 121, 183, 183], dtype=int32)]
#
# 2490893 with image url: https://cdn.nos.nl/image/2023/09/18/1009039/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2502158 with image url: https://cdn.nos.nl/image/2023/12/19/1036763/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2492083 with image url: https://cdn.nos.nl/image/2023/09/27/1012022/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2502712 with image url: https://cdn.nos.nl/image/2023/12/24/1038104/1024x576a.jpg
# #HAAR: 1 at: [[580 167  68  68]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([580, 167,  68,  68], dtype=int32)]
#
# 2488929 with image url: https://cdn.nos.nl/image/2023/09/02/1004299/1024x576a.jpg
# #HAAR: 4 at: [[971 285  51  51]
#  [424 390 146 146]
#  [268 278  88  88]
#  [879 262 105 105]]
# #FR: 4 at: [(425, 397, 129, 129), (976, 290, 43, 44), (255, 275, 89, 90), (892, 275, 90, 90)]
# #COMBINED: 8
# #UNIQUE: 4 at: [array([971, 285,  51,  51], dtype=int32), array([424, 390, 146, 146], dtype=int32), array([268, 278,  88,  88], dtype=int32), array([879, 262, 105, 105], dtype=int32)]
#
# 2492787 with image url: https://cdn.nos.nl/image/2023/10/03/1013562/1024x576a.jpg
# #HAAR: 1 at: [[383  41 359 359]]
# #FR: 1 at: [(297, 40, 462, 462)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([383,  41, 359, 359], dtype=int32)]
#
# 2502863 with image url: https://cdn.nos.nl/image/2023/12/26/1038442/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2489408 with image url: https://cdn.nos.nl/image/2023/09/06/1005485/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2492038 with image url: https://cdn.nos.nl/image/2023/09/27/1011915/1024x576a.jpg
# #HAAR: 2 at: [[ 96 227  85  85]
#  [356 352  85  85]]
# #FR: 0 at: []
# #COMBINED: 2
# #UNIQUE: 2 at: [array([ 96, 227,  85,  85], dtype=int32), array([356, 352,  85,  85], dtype=int32)]
#
# 2502480 with image url: https://cdn.nos.nl/image/2023/12/22/1037684/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2492587 with image url: https://cdn.nos.nl/image/2023/10/02/1013188/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2497270 with image url: https://cdn.nos.nl/image/2023/11/09/1024710/1024x576a.jpg
# #HAAR: 3 at: [[572  38  63  63]
#  [324 119  53  53]
#  [445 156 156 156]]
# #FR: 1 at: [(570, 39, 63, 62)]
# #COMBINED: 4
# #UNIQUE: 3 at: [array([572,  38,  63,  63], dtype=int32), array([324, 119,  53,  53], dtype=int32), array([445, 156, 156, 156], dtype=int32)]
#
# 2491980 with image url: https://cdn.nos.nl/image/2023/09/27/1011807/1024x576a.jpg
# #HAAR: 1 at: [[808 422  52  52]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([808, 422,  52,  52], dtype=int32)]
#
# 2495787 with image url: https://cdn.nos.nl/image/2023/10/29/1021051/1024x576a.jpg
# #HAAR: 2 at: [[252  79 208 208]
#  [694 312 163 163]]
# #FR: 1 at: [(700, 322, 155, 155)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([252,  79, 208, 208], dtype=int32), array([694, 312, 163, 163], dtype=int32)]
#
# 2501699 with image url: https://cdn.nos.nl/image/2023/12/15/1035615/1024x576a.jpg
# #HAAR: 2 at: [[145 140  61  61]
#  [733 250 104 104]]
# #FR: 0 at: []
# #COMBINED: 2
# #UNIQUE: 2 at: [array([145, 140,  61,  61], dtype=int32), array([733, 250, 104, 104], dtype=int32)]
#
# 2494968 with image url: https://cdn.nos.nl/image/2023/10/22/1018962/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2500628 with image url: https://cdn.nos.nl/image/2023/12/06/1032922/1024x576a.jpg
# #HAAR: 2 at: [[883 146  34  34]
#  [180  86  97  97]]
# #FR: 0 at: []
# #COMBINED: 2
# #UNIQUE: 2 at: [array([883, 146,  34,  34], dtype=int32), array([180,  86,  97,  97], dtype=int32)]
#
# 2497861 with image url:
# 2491338 with image url: https://cdn.nos.nl/image/2023/09/21/1010221/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 2502132 with image url: https://cdn.nos.nl/image/2023/12/19/1036716/1024x576a.jpg
# #HAAR: 0 at: ()
# #FR: 1 at: [(526, 99, 321, 321)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(526, 99, 321, 321)]

# %% [markdown]
# ### Continue to full dataset after inspection

# %%
from methods_data_collection import detect_cut_save_faces

# Create the output directory
output_dir_news_nos = 'datasets/images/isolated_news_faces_nos'
os.makedirs(output_dir_news_nos, exist_ok=True)

detect_cut_save_faces(nos_articles, 'img_link', 'id', output_dir_news_nos)
# Out:
# Scraping at...:   0%|          | 0/3592 [00:00<?, ?it/s]
# Image at https://cdn.nos.nl/image/2023/11/30/1030850/1024x576a.jpg does not have 3 channels.
# Image at https://cdn.nos.nl/image/2023/11/18/1027161/1024x576a.jpg does not have 3 channels.
# Image at https://cdn.nos.nl/image/2023/11/15/1026198/1024x576a.jpg does not have 3 channels.
# Image at https://cdn.nos.nl/image/2023/10/09/1015417/1024x576a.jpg does not have 3 channels.
# Image at https://cdn.nos.nl/image/2023/10/04/1013835/1024x576a.jpg does not have 3 channels.

# %% [markdown]
# ### b. NU.nl
#
# ##### Set up data infrastructure
# Load articles that are not exclusively about sports obtained in script #1 of this directory, create a test set

# %%
nu_articles = pd.read_parquet('datasets/nu_articles_election_period.parquet')

# %%
print(nu_articles.shape)
print(nu_articles.columns)
# Out:
# (5350, 13)
# Index(['id', 'title', 'datetime', 'url', 'date', 'category', 'tags',
#        'main_category', 'img_link', 'paragraphs', 'first_paragraph',
#        'comments_count', 'media_dict'],
#       dtype='object')

# %%
nu_articles_test = nu_articles.sample(n = 50, random_state = 0)

# %% [markdown]
# #### Test if methods work as expected, including print statements

# %%
from methods_data_collection import detect_cut_save_faces_test

# Create the output directory
output_dir_news_nu_test = 'datasets/images/isolated_news_faces_nu_test'
os.makedirs(output_dir_news_nu_test, exist_ok=True)

detect_cut_save_faces_test(nu_articles_test, 'img_link', 'id', output_dir_news_nu_test)
# Out:
# Test scraping at...:   0%|          | 0/50 [00:00<?, ?it/s]
# 6287268 with image url: https://media.nu.nl/m/44axqdaabi9p_wd854
# #HAAR: 1 at: [[380  41 114 114]]
# #FR: 1 at: [(394, 56, 90, 90)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([380,  41, 114, 114], dtype=int32)]
#
# 6290441 with image url: https://media.nu.nl/m/gzgxq6caxxfx_wd854
# #HAAR: 2 at: [[279 369  57  57]
#  [526 151 168 168]]
# #FR: 1 at: [(510, 139, 186, 186)]
# #COMBINED: 3
# #UNIQUE: 2 at: [array([279, 369,  57,  57], dtype=int32), array([526, 151, 168, 168], dtype=int32)]
#
# 6292477 with image url: https://media.nu.nl/m/crvxyuma7ibd_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6279734 with image url: https://media.nu.nl/m/omixlhna3zd0_wd854
# #HAAR: 1 at: [[271  52 207 207]]
# #FR: 1 at: [(283, 77, 186, 186)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([271,  52, 207, 207], dtype=int32)]
#
# 6285152 with image url: https://media.nu.nl/m/t44xubxaya8d_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6284739 with image url: https://media.nu.nl/m/9mrxcvtapcyb_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6291987 with image url: https://media.nu.nl/m/t7vx3lba5dd3_wd854
# #HAAR: 3 at: [[559  65  81  81]
#  [228  76  81  81]
#  [680 230  72  72]]
# #FR: 2 at: [(560, 72, 75, 74), (229, 88, 74, 75)]
# #COMBINED: 5
# #UNIQUE: 3 at: [array([559,  65,  81,  81], dtype=int32), array([228,  76,  81,  81], dtype=int32), array([680, 230,  72,  72], dtype=int32)]
#
# 6295379 with image url: https://media.nu.nl/m/azvxlnkatqkw_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6282089 with image url: https://media.nu.nl/m/8p3xkrya6n2m_wd854
# #HAAR: 0 at: ()
# #FR: 4 at: [(342, 175, 108, 108), (43, 182, 52, 52), (187, 163, 75, 74), (314, 182, 52, 52)]
# #COMBINED: 4
# #UNIQUE: 4 at: [(342, 175, 108, 108), (43, 182, 52, 52), (187, 163, 75, 74), (314, 182, 52, 52)]
#
# 6289140 with image url: https://media.nu.nl/m/fvzx0qua61lc_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6295494 with image url: https://media.nu.nl/m/efexfwzabgm1_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6294450 with image url: https://media.nu.nl/m/dayxj67aakvk_wd854
# #HAAR: 1 at: [[702 366 109 109]]
# #FR: 1 at: [(304, 57, 185, 185)]
# #COMBINED: 2
# #UNIQUE: 2 at: [array([702, 366, 109, 109], dtype=int32), (304, 57, 185, 185)]
#
# 6281457 with image url: https://media.nu.nl/m/lmaxyt0aw55o_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6289390 with image url: https://media.nu.nl/m/u53x48bad18o_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6295109 with image url: https://media.nu.nl/m/824xgvba1wzs_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6295366 with image url: https://media.nu.nl/m/muyxornaydg1_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6294471 with image url: https://media.nu.nl/m/6hzxh4rajz81_wd854
# #HAAR: 1 at: [[313  57  89  89]]
# #FR: 1 at: [(320, 72, 75, 74)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([313,  57,  89,  89], dtype=int32)]
#
# 6278979 with image url: https://media.nu.nl/m/e6bxb83a8n6s_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6286249 with image url: https://media.nu.nl/m/1n7xafoan26i_wd854
# #HAAR: 2 at: [[109  23  51  51]
#  [406  50  58  58]]
# #FR: 2 at: [(412, 55, 51, 52), (112, 31, 44, 43)]
# #COMBINED: 4
# #UNIQUE: 2 at: [array([109,  23,  51,  51], dtype=int32), array([406,  50,  58,  58], dtype=int32)]
#
# 6290962 with image url: https://media.nu.nl/m/mh2xs76a89wg_wd854
# #HAAR: 0 at: ()
# #FR: 2 at: [(294, 235, 108, 108), (454, 110, 129, 129)]
# #COMBINED: 2
# #UNIQUE: 2 at: [(294, 235, 108, 108), (454, 110, 129, 129)]
#
# 6281272 with image url: https://media.nu.nl/m/8ysxy2yapcjt_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6294689 with image url: https://media.nu.nl/m/bzux2lfajqxh_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6289306 with image url: https://media.nu.nl/m/9pfxf9zah4zx_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6288919 with image url: https://media.nu.nl/m/jh5x1o6a3m60_wd854
# #HAAR: 4 at: [[550 106  51  51]
#  [591 145  41  41]
#  [595 338  57  57]
#  [458 311  55  55]]
# #FR: 4 at: [(593, 150, 36, 36), (591, 336, 62, 62), (400, 147, 52, 52), (4, 329, 62, 62)]
# #COMBINED: 8
# #UNIQUE: 6 at: [array([550, 106,  51,  51], dtype=int32), array([591, 145,  41,  41], dtype=int32), array([595, 338,  57,  57], dtype=int32), array([458, 311,  55,  55], dtype=int32), (400, 147, 52, 52), (4, 329, 62, 62)]
#
# 6291743 with image url: https://media.nu.nl/m/85hxql6a1flz_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6283116 with image url: https://media.nu.nl/m/fxpxe59absfk_wd854
# #HAAR: 1 at: [[731  68  67  67]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([731,  68,  67,  67], dtype=int32)]
#
# 6288749 with image url: https://media.nu.nl/m/eggx14taoo34_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6289572 with image url: https://media.nu.nl/m/b4dxnyzao90d_wd854
# #HAAR: 0 at: ()
# #FR: 1 at: [(440, 113, 52, 51)]
# #COMBINED: 1
# #UNIQUE: 1 at: [(440, 113, 52, 51)]
#
# 6286339 with image url: https://media.nu.nl/m/tbpx7ovazhxc_wd854
# #HAAR: 1 at: [[665 379  50  50]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([665, 379,  50,  50], dtype=int32)]
#
# 6283695 with image url: https://media.nu.nl/m/ud1xv2wagzmq_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6295606 with image url: https://media.nu.nl/m/wvkxdd9a8do4_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6284676 with image url: https://media.nu.nl/m/0y0xhymaprf4_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6279280 with image url: https://media.nu.nl/m/h5cxualagzy4_wd854
# #HAAR: 1 at: [[426 107 170 170]]
# #FR: 1 at: [(425, 133, 155, 155)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([426, 107, 170, 170], dtype=int32)]
#
# 6289448 with image url: https://media.nu.nl/m/v3sxi1lamyu6_wd854
# #HAAR: 1 at: [[670 109  54  54]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([670, 109,  54,  54], dtype=int32)]
#
# 6293293 with image url: https://media.nu.nl/m/r8wxv9ea26v3_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6281807 with image url: https://media.nu.nl/m/0mtxl9ca32t8_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6289577 with image url: https://media.nu.nl/m/gppxfjnavn6b_wd854
# #HAAR: 1 at: [[439 331  84  84]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([439, 331,  84,  84], dtype=int32)]
#
# 6285904 with image url: https://media.nu.nl/m/xz3x1i9aro7p_wd854
# #HAAR: 1 at: [[296 134  37  37]]
# #FR: 0 at: []
# #COMBINED: 1
# #UNIQUE: 1 at: [array([296, 134,  37,  37], dtype=int32)]
#
# 6286994 with image url: https://media.nu.nl/m/egkxy8la2gzq_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6289590 with image url: https://media.nu.nl/m/9gvxy72aikly_wd854
# #HAAR: 2 at: [[500 283  74  74]
#  [245 376  55  55]]
# #FR: 0 at: []
# #COMBINED: 2
# #UNIQUE: 2 at: [array([500, 283,  74,  74], dtype=int32), array([245, 376,  55,  55], dtype=int32)]
#
# 6294027 with image url: https://media.nu.nl/m/lghxwobavzfp_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6282227 with image url: https://media.nu.nl/m/2yvx13davtv8_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6286733 with image url: https://media.nu.nl/m/owdxckhavhxq_wd854
# #HAAR: 8 at: [[281  30  86  86]
#  [470  40 104 104]
#  [200 281  52  52]
#  [359  25 105 105]
#  [430 183  76  76]
#  [291 256 104 104]
#  [398 282  97  97]
#  [165 340  99  99]]
# #FR: 1 at: [(287, 38, 74, 75)]
# #COMBINED: 9
# #UNIQUE: 8 at: [array([281,  30,  86,  86], dtype=int32), array([470,  40, 104, 104], dtype=int32), array([200, 281,  52,  52], dtype=int32), array([359,  25, 105, 105], dtype=int32), array([430, 183,  76,  76], dtype=int32), array([291, 256, 104, 104], dtype=int32), array([398, 282,  97,  97], dtype=int32), array([165, 340,  99,  99], dtype=int32)]
#
# 6288815 with image url: https://media.nu.nl/m/rzsxisaafv7a_wd854
# #HAAR: 1 at: [[388  77 121 121]]
# #FR: 1 at: [(390, 92, 107, 107)]
# #COMBINED: 2
# #UNIQUE: 1 at: [array([388,  77, 121, 121], dtype=int32)]
#
# 6295820 with image url: https://media.nu.nl/m/f04xtdxa4v0i_wd854
# #HAAR: 2 at: [[649 150  37  37]
#  [297 139  37  37]]
# #FR: 3 at: [(649, 150, 36, 36), (293, 138, 36, 36), (741, 106, 36, 36)]
# #COMBINED: 5
# #UNIQUE: 3 at: [array([649, 150,  37,  37], dtype=int32), array([297, 139,  37,  37], dtype=int32), (741, 106, 36, 36)]
#
# 6282076 with image url: https://media.nu.nl/m/66vxtiea4qn0_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6292444 with image url: https://media.nu.nl/m/6kxxx8va4iud_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6279304 with image url: https://media.nu.nl/m/h9ox6y5a0u4v_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6290866 with image url: https://media.nu.nl/m/kfcxz82a28s5_wd854
# #HAAR: 0 at: ()
# #FR: 0 at: []
# #COMBINED: 0
# #UNIQUE: 0 at: []
#
# 6285448 with image url: https://media.nu.nl/m/ad7xp9wa8leb_wd854
# #HAAR: 4 at: [[294  47 121 121]
#  [179 191 149 149]
#  [375 225 113 113]
#  [164 308 129 129]]
# #FR: 3 at: [(384, 245, 90, 90), (199, 211, 107, 108), (294, 68, 108, 107)]
# #COMBINED: 7
# #UNIQUE: 4 at: [array([294,  47, 121, 121], dtype=int32), array([179, 191, 149, 149], dtype=int32), array([375, 225, 113, 113], dtype=int32), array([164, 308, 129, 129], dtype=int32)]

# %% [markdown]
# ### Continue to full dataset after inspection

# %%
from methods_data_collection import detect_cut_save_faces

# Create the output directory
output_dir_news_nu = 'datasets/images/isolated_news_faces_nu'
os.makedirs(output_dir_news_nu, exist_ok=True)

detect_cut_save_faces(nu_articles, 'img_link', 'id', output_dir_news_nu)
# Out:
# Scraping at...:   0%|          | 0/5350 [00:00<?, ?it/s]
# Image at https://media.nu.nl/m/434xfyia0vjl_wd854 does not have 3 channels.
# Image at https://media.nu.nl/m/vgsxgvgau0zu_wd854 does not have 3 channels.
# Image at https://media.nu.nl/m/er7x411ajrw9_wd854 does not have 3 channels.
# Image at https://media.nu.nl/m/vgsxgvgau0zu_wd854 does not have 3 channels.
# Image at https://media.nu.nl/m/o9bxn7pahiak_wd854 does not have 3 channels.
# Image at https://media.nu.nl/m/h4vxdwaasvdf_wd854 does not have 3 channels.
